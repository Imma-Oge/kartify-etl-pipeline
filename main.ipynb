# %%
import sys
sys.path.append('../')

# %%
from src.connections import get_postgres_engine, get_snowflake_engine

# %%
snowflake_engine = get_snowflake_engine()

# %%
postgres_engine = get_postgres_engine()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 postgres_engine = get_postgres_engine()
#
# File ~\Desktop\kartify_projects\kartify-etl-pipeline\src\connections.py:11, in get_postgres_engine()
#      10 def get_postgres_engine():
# ---> 11     url=sa_URL.create(
#      12     driver=("postgresql+psycopg2"),
#      13     username=os.getenv("db_user"),
#      14     password=os.getenv("db_password"),
#      15     host=os.getenv("db_host"),
#      16     port=int(os.getenv("db_port")),
#      17     database=os.getenv("db_database"),
#      18     query={"sslmode": "require"}
#      19     )
#      20     return create_engine(url)
#
# TypeError: URL.create() got an unexpected keyword argument 'driver'

# %%
with snowflake_engine.connect() as conn:
    print(f"sucessfully connected to snowflake")
# Out:
# sucessfully connected to snowflake
